# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyabavse27/jiyabavse.github.io/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step1:Import Library
import pandas as pd

# %%
#Step2: Read Dataset
df=pd.read_csv('/content/Ice Cream.csv')

# %%
df.head(2)
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
#Step3:Define X and Y
df.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
y=df['Revenue']
x=df[['Temperature']]

# %%
#Step4:Train Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.8, random_state=2529)
x_train.shape, x_test.shape
# Out:
# ((400, 1), (100, 1))

# %%
import seaborn as sns
sns.regplot(x='Temperature', y='Revenue', data=df, fit_reg=False)
# Out:
# <Axes: xlabel='Temperature', ylabel='Revenue'>

# %%
#Step5: Select model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#Step6:Train model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_ , model.coef_
# Out:
# (np.float64(43.34145600257415), array([21.49561785]))

# %%
#Step7: Prediction
y_pred=model.predict(x_test)

# %%
#Stesp8: Evaluate
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.040411691653390244

# %%
#Visualizing the result
import matplotlib.pyplot as plt
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_test, y_test, color='red')
plt.title('Tempearture Vs Revenue')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()
